# %%
import os
from PIL import Image
from collections import defaultdict

# === CONFIGURATION ===
NUM_FOLDERS = None           # Set to None to process all folders or a specific number (e.g., 5)
NUM_FILES_PER_FOLDER = None  # Set to None to process all cropped images per folder or a specific number (e.g., 5)
OUTPUT_PATH = 'out_data/'
DESIRED_COUNT = 300

def check_plu_balance(output_path=OUTPUT_PATH, desired_count=DESIRED_COUNT):
    """
    Scans a single folder (`output_path`) for .png images. 
    Group them by PLU (the filename prefix before the first '_').
    
    Returns:
        plu_to_files (dict): {plu: [list_of_png_filenames]}
        missing_dict (dict): {plu: how_many_images_missing_to_reach_desired_count}
        all_balanced (bool): True if every PLU has at least desired_count images
    """
    # Gather all .png files in out_data
    all_png = [f for f in os.listdir(output_path) if f.lower().endswith('.png')]
    
    # Organize by PLU
    plu_to_files = defaultdict(list)
    for filename in all_png:
        parts = filename.split('-', 1)  # split into [PLU, rest...]
        if len(parts) == 2:
            plu = parts[0]
            plu_to_files[plu].append(filename)
        else:
            # If there's no underscore, skip or treat the entire filename as PLU
            continue
    
    if not plu_to_files:
        print("No .png images found in the output folder.")
        return {}, {}, True
    
    # Build missing dict
    missing_dict = {}
    all_balanced = True
    
    for plu, files in plu_to_files.items():
        count = len(files)
        short = desired_count - count
        missing_dict[plu] = max(short, 0)
        if short > 0:
            all_balanced = False

    return plu_to_files, missing_dict, all_balanced
import random
from PIL import Image

def balance_plu_images(output_path=OUTPUT_PATH, desired_count=DESIRED_COUNT):
    """
    For each PLU that has fewer than `desired_count` images, 
    apply augmentations (rotations/flips) to the seed images 
    until the PLU has at least `desired_count` images.
    """
    plu_to_files, missing_dict, all_balanced = check_plu_balance(output_path, desired_count)
    
    # Early exit if everything's balanced
    if all_balanced:
        print(f"✅ All PLUs have at least {desired_count} images already.")
        return
    
    # Process each PLU
    for plu, missing in missing_dict.items():
        if missing <= 0:
            print(f"⏭  PLU {plu} is already at {len(plu_to_files[plu])} images, skipping.")
            continue
        
        # We'll only treat '_cropped.png' files as seeds
        seed_files = [f for f in plu_to_files[plu] if f.endswith('_cropped.png')]
        
        # If no cropped files are found, you might want to treat all .png as seed:
        if not seed_files:
            print(f"⚠️  PLU {plu} has no '_cropped.png' seeds. Using all files as seeds.")
            seed_files = plu_to_files[plu]

        current_count = len(plu_to_files[plu])
        print(f"⚙️  Balancing PLU {plu}. Currently has {current_count}, needs {missing} more.")
        
        seed_index = 0  # We'll cycle through seeds in round-robin fashion
        
        while current_count < desired_count:
            seed_name = seed_files[seed_index]
            seed_index = (seed_index + 1) % len(seed_files)

            seed_path = os.path.join(output_path, seed_name)
            base_plu = seed_name.split('-', 1)[0]  # e.g. "4011"
            base_rest = seed_name.split('-', 1)[1].replace('.png','')  # e.g. "19_cropped"

            try:
                img = Image.open(seed_path)
            except Exception as e:
                print(f"⚠️  Could not open {seed_path}: {e}")
                continue

            # Produce a few augmentations for each seed pass
            # until we reach desired_count. 
            # For example, let's produce up to 4 new images per loop:
            
            # 1) Rotate 90
            if current_count < desired_count:
                out_file = f"{base_plu}-{base_rest}_aug_rot90_{current_count}.png"
                out_path = os.path.join(output_path, out_file)
                img.rotate(90, expand=True).save(out_path)
                plu_to_files[plu].append(out_file)  # Update in-memory
                current_count += 1

            # 2) Horizontal Flip
            if current_count < desired_count:
                out_file = f"{base_plu}-{base_rest}_aug_flipH_{current_count}.png"
                out_path = os.path.join(output_path, out_file)
                img.transpose(Image.FLIP_LEFT_RIGHT).save(out_path)
                plu_to_files[plu].append(out_file)
                current_count += 1

            # 3) Vertical Flip
            if current_count < desired_count:
                out_file = f"{base_plu}-{base_rest}_aug_flipV_{current_count}.png"
                out_path = os.path.join(output_path, out_file)
                img.transpose(Image.FLIP_TOP_BOTTOM).save(out_path)
                plu_to_files[plu].append(out_file)
                current_count += 1

            # 4) Combined Flip + Rotate
            if current_count < desired_count:
                out_file = f"{base_plu}-{base_rest}_aug_flipH_rot90_{current_count}.png"
                out_path = os.path.join(output_path, out_file)
                flipped_h = img.transpose(Image.FLIP_LEFT_RIGHT)
                flipped_h.rotate(90, expand=True).save(out_path)
                plu_to_files[plu].append(out_file)
                current_count += 1
        
        print(f"✅ PLU {plu} is now at {current_count} images.")


if __name__ == '__main__':
    # Check how many images each PLU has initially
    plu_to_files, missing_dict, all_balanced = check_plu_balance(OUTPUT_PATH, DESIRED_COUNT)
    
    print("\n🔍 Before balancing:")
    for plu in sorted(plu_to_files.keys()):
        count = len(plu_to_files[plu])
        print(f"  PLU {plu}: has {count} images, needs {missing_dict[plu]}")
    print("Balanced already?", all_balanced)
    
    # Balance them
    balance_plu_images(OUTPUT_PATH, DESIRED_COUNT)

    # Check again
    plu_to_files, missing_dict, all_balanced = check_plu_balance(OUTPUT_PATH, DESIRED_COUNT)
    print("\n🔍 After balancing:")
    for plu in sorted(plu_to_files.keys()):
        count = len(plu_to_files[plu])
        print(f"  PLU {plu}: has {count} images, needs {missing_dict[plu]}")
    print("Balanced now?", all_balanced)
# Out:
# ✅ Saved rotated 90° image: out_data/4011/4011-673_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-673_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-673_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-673_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-673_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-673_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-891_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-891_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-891_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-891_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-891_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-891_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-950_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-950_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-950_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-950_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-950_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-950_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-631_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-631_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-631_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-631_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-631_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-631_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1301_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1301_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1301_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1301_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1301_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1301_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1116_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1116_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1116_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1116_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1116_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1116_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-898_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-898_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-898_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-898_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-898_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-898_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1364_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1364_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1364_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1364_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1364_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1364_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1023_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1023_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1023_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1023_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1023_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1023_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-151_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-151_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-151_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-151_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-151_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-151_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-563_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-563_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-563_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-563_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-563_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-563_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1053_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1053_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1053_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1053_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1053_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1053_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-19_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-19_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-19_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-19_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-19_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-19_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-809_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-809_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-809_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-809_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-809_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-809_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-682_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-682_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-682_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-682_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-682_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-682_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-810_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-810_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-810_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-810_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-810_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-810_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1099_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1099_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1099_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1099_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1099_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1099_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1078_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1078_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1078_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1078_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1078_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1078_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-42_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-42_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-42_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-42_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-42_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-42_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1056_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1056_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1056_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1056_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1056_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1056_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-124_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-124_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-124_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-124_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-124_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-124_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1368_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1368_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1368_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1368_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1368_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1368_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-385_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-385_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-385_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-385_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-385_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-385_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-955_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-955_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-955_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-955_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-955_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-955_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1151_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1151_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1151_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1151_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1151_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1151_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-141_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-141_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-141_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-141_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-141_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-141_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-27_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-27_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-27_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-27_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-27_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-27_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-676_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-676_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-676_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-676_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-676_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-676_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-173_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-173_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-173_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-173_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-173_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-173_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-531_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-531_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-531_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-531_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-531_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-531_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1071_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1071_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1071_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1071_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1071_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1071_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-949_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-949_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-949_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-949_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-949_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-949_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-726_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-726_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-726_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-726_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-726_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-726_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-725_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-725_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-725_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-725_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-725_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-725_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-999_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-999_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-999_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-999_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-999_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-999_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1072_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1072_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1072_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1072_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1072_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1072_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-349_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-349_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-349_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-349_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-349_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-349_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-532_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-532_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-532_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-532_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-532_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-532_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-675_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-675_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-675_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-675_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-675_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-675_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-142_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-142_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-142_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-142_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-142_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-142_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-956_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-956_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-956_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-956_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-956_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-956_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1055_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1055_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1055_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1055_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1055_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1055_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-281_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-281_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-281_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-281_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-281_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-281_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-943_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-943_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-943_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-943_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-943_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-943_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1417_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1417_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1417_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1417_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1417_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1417_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-565_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-565_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-565_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-565_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-565_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-565_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-222_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-222_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-222_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-222_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-222_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-222_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1232_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1232_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1232_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1232_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1232_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1232_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-179_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-179_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-179_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-179_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-179_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-179_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-165_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-165_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-165_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-165_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-165_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-165_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1362_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1362_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1362_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1362_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1362_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1362_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1200_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1200_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1200_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1200_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1200_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1200_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-34_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-34_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-34_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-34_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-34_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-34_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-279_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-279_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-279_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-279_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-279_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-279_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1020_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1020_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1020_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1020_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1020_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1020_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-284_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-284_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-284_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-284_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-284_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-284_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1386_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1386_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1386_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1386_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1386_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1386_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1100_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1100_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1100_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1100_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1100_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1100_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1420_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1420_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1420_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1420_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1420_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1420_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1339_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1339_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1339_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1339_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1339_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1339_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1115_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1115_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1115_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1115_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1115_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1115_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1198_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1198_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1198_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1198_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1198_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1198_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-632_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-632_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-632_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-632_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-632_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-632_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1372_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1372_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1372_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1372_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1372_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1372_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1340_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1340_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1340_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1340_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1340_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1340_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1070_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1070_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1070_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1070_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1070_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1070_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1000_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1000_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1000_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1000_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1000_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1000_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-727_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-727_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-727_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-727_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-727_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-727_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1150_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1150_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1150_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1150_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1150_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1150_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-677_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-677_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-677_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-677_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-677_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-677_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-342_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-342_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-342_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-342_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-342_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-342_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-125_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-125_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-125_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-125_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-125_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-125_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1057_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1057_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1057_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1057_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1057_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1057_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-391_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-391_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-391_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-391_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-391_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-391_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-419_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-419_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-419_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-419_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-419_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-419_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1065_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1065_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1065_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1065_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1065_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1065_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1015_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1015_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1015_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1015_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1015_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1015_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1427_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1427_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1427_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1427_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1427_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1427_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1022_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1022_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1022_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1022_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1022_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1022_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-249_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-249_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-249_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-249_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-249_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-249_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-159_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-159_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-159_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-159_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-159_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-159_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1419_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1419_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1419_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1419_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1419_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1419_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1005_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1005_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1005_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1005_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1005_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1005_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1117_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1117_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1117_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1117_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1117_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1117_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1342_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1342_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1342_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1342_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1342_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1342_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1094_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1094_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1094_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1094_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1094_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1094_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-672_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-672_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-672_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-672_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-672_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-672_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-951_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-951_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-951_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-951_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-951_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-951_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1126_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1126_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1126_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1126_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1126_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1126_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1341_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1341_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1341_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1341_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1341_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1341_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1199_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1199_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1199_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1199_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1199_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1199_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1434_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1434_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1434_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1434_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1434_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1434_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1303_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1303_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1303_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1303_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1303_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1303_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-633_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-633_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-633_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-633_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-633_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-633_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-839_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-839_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-839_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-839_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-839_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-839_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-214_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-214_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-214_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-214_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-214_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-214_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1338_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1338_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1338_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1338_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1338_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1338_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-344_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-344_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-344_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-344_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-344_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-344_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-256_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-256_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-256_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-256_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-256_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-256_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1051_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1051_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1051_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1051_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1051_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1051_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-511_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-511_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-511_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-511_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-511_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-511_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1021_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1021_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1021_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1021_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1021_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1021_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-728_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-728_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-728_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-728_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-728_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-728_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1066_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1066_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1066_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1066_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1066_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1066_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1424_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1424_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1424_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1424_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1424_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1424_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1016_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1016_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1016_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1016_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1016_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1016_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-1363_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-1363_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-1363_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-1363_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-1363_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-1363_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-564_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-564_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/4011/4011-564_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/4011/4011-564_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/4011/4011-564_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/4011/4011-564_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/4011/4011-280_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/4011/4011-280_cropped_rot180.png
# ...
# ✅ Saved rotated 180° image: out_data/90433924/90433924-118_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-118_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-118_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-118_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-118_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-189_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-189_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-189_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-189_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-189_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-189_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-23_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-23_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-23_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-23_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-23_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-23_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-104_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-104_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-104_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-104_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-104_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-104_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-201_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-201_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-201_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-201_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-201_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-201_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-264_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-264_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-264_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-264_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-264_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-264_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-18_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-18_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-18_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-18_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-18_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-18_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-214_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-214_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-214_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-214_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-214_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-214_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-46_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-46_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-46_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-46_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-46_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-46_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-111_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-111_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-111_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-111_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-111_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-111_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-180_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-180_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-180_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-180_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-180_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-180_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-208_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-208_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-208_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-208_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-208_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-208_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-74_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-74_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-74_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-74_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-74_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-74_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-153_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-153_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-153_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-153_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-153_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-153_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-89_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-89_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-89_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-89_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-89_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-89_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-114_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-114_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-114_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-114_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-114_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-114_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-33_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-33_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-33_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-33_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-33_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-33_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-211_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-211_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-211_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-211_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-211_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-211_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-71_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-71_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-71_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-71_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-71_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-71_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-185_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-185_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-185_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-185_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-185_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-185_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-108_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-108_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-108_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-108_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-108_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-108_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-190_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-190_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-190_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-190_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-190_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-190_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-246_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-246_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-246_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-246_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-246_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-246_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-99_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-99_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-99_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-99_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-99_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-99_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-3_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-3_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-3_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-3_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-3_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-3_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-295_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-295_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-295_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-295_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-295_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-295_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-64_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-64_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-64_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-64_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-64_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-64_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-78_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-78_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-78_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-78_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-78_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-78_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-85_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-85_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-85_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-85_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-85_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-85_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-289_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-289_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-289_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-289_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-289_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-289_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-26_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-26_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-26_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-26_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-26_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-26_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-171_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-171_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-171_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-171_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-171_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-171_cropped_flipH_rot90.png
# ✅ Saved rotated 90° image: out_data/90433924/90433924-56_cropped_rot90.png
# ✅ Saved rotated 180° image: out_data/90433924/90433924-56_cropped_rot180.png
# ✅ Saved rotated 270° image: out_data/90433924/90433924-56_cropped_rot270.png
# ✅ Saved horizontal flip image: out_data/90433924/90433924-56_cropped_flipH.png
# ✅ Saved vertical flip image: out_data/90433924/90433924-56_cropped_flipV.png
# ✅ Saved horizontal flip rotated 90° image: out_data/90433924/90433924-56_cropped_flipH_rot90.png
# Skipping folder '94011' because it already has 225 images.
